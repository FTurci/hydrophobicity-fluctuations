# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import sem

# %%
df = pd.read_csv("output.nvt.csv")

# %%
df.plot('step','temperature', legend=False)
# target_rho = 0.96
# plt.plot(df['step'], np.ones_like(df['step'])*target_rho, color='darkorange')
# Out:
# <AxesSubplot:xlabel='step'>

# %%
# df.plot('step','density', ylabel=r"$\rho~[g/cm^3]$", color='k', legend=False)
# # plt.plot(df['step'], df['density'])
# target_rho = 0.95981
# plt.plot(df['step'], np.ones_like(df['step'])*target_rho, color='darkorange')

# # plt.ylim(0.75,0.9)
# my_rho = df.loc[df['step']>10000,'density'].mean()
# print(my_rho, (my_rho-target_rho)/target_rho)

# %%
df.plot('step', 'pressure')
plt.ylim(-2000,2000)
# Out:
# (-2000.0, 2000.0)

# %%
pressure = df.loc[df['step']>1000,'pressure']

stride = 5
p = pressure[::stride]

print(len(p),"values")
print("pressure", p.mean(), sem(p), np.std(p))
# Out:
# 86089 values
# pressure 29.35058639068243 1.0875253981477884 319.0881804302405

# %%
from statsmodels.tsa.stattools import acf

plt.plot(acf(pressure))

# %%
density = df.loc[df['step']>10000,'density']
print("density", density.mean(), sem(density))
# Out:
# density 0.9598100011937055 1.7302468947406487e-18

# %%
M = 66816.852 * 0.95989139

# %%
(M/0.95981)**(1./3)/2
# Out:
# 20.289793005198288
